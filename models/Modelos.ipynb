# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'..\data\processed\teleco-ML.csv')

# %%
X = df.drop(columns=['Churn_Yes','gender_Male','PhoneService_Yes','Partner_Yes','tenure_group_13-24', 'tenure_group_25-48', 'tenure_group_49-60',
       'tenure_group_61-72','charge_ratio'])
y = df['Churn_Yes']

# %%
df[['tenure','MonthlyCharges','TotalCharges']] = np.log1p(df[['tenure','MonthlyCharges','TotalCharges']])

# %%
plt.figure(figsize=(22,8))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >
